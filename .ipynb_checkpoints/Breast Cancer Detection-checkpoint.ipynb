# %%
# Import all the necessary libraries

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
# !wget 'https://cainvas-static.s3.amazonaws.com/media/user_data/kkharbanda90/data.zip'

# !unzip -qo data.zip 
# !rm data.zip
# Out:
# --2021-08-21 08:02:42--  https://cainvas.ai-tech.systems:9000/user/kkharbanda90/lab//home/jupyter-kkharbanda90/data.zip
# Resolving cainvas.ai-tech.systems (cainvas.ai-tech.systems)... 65.1.254.242
# Connecting to cainvas.ai-tech.systems (cainvas.ai-tech.systems)|65.1.254.242|:9000... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /hub/api/oauth2/authorize?client_id=jupyterhub-user-kkharbanda90&redirect_uri=%2Fuser%2Fkkharbanda90%2Foauth_callback&response_type=code&state=eyJ1dWlkIjogImM2YTQ3NWIxZTg2ZDQzZTE4OGM1NDFkNTE4NjM1ZGQ0IiwgIm5leHRfdXJsIjogIi91c2VyL2traGFyYmFuZGE5MC9sYWIvL2hvbWUvanVweXRlci1ra2hhcmJhbmRhOTAvZGF0YS56aXAifQ [following]
# --2021-08-21 08:02:42--  https://cainvas.ai-tech.systems:9000/hub/api/oauth2/authorize?client_id=jupyterhub-user-kkharbanda90&redirect_uri=%2Fuser%2Fkkharbanda90%2Foauth_callback&response_type=code&state=eyJ1dWlkIjogImM2YTQ3NWIxZTg2ZDQzZTE4OGM1NDFkNTE4NjM1ZGQ0IiwgIm5leHRfdXJsIjogIi91c2VyL2traGFyYmFuZGE5MC9sYWIvL2hvbWUvanVweXRlci1ra2hhcmJhbmRhOTAvZGF0YS56aXAifQ
# Reusing existing connection to cainvas.ai-tech.systems:9000.
# HTTP request sent, awaiting response... 302 Found
# Location: /hub/login?next=%2Fhub%2Fapi%2Foauth2%2Fauthorize%3Fclient_id%3Djupyterhub-user-kkharbanda90%26redirect_uri%3D%252Fuser%252Fkkharbanda90%252Foauth_callback%26response_type%3Dcode%26state%3DeyJ1dWlkIjogImM2YTQ3NWIxZTg2ZDQzZTE4OGM1NDFkNTE4NjM1ZGQ0IiwgIm5leHRfdXJsIjogIi91c2VyL2traGFyYmFuZGE5MC9sYWIvL2hvbWUvanVweXRlci1ra2hhcmJhbmRhOTAvZGF0YS56aXAifQ [following]
# --2021-08-21 08:02:42--  https://cainvas.ai-tech.systems:9000/hub/login?next=%2Fhub%2Fapi%2Foauth2%2Fauthorize%3Fclient_id%3Djupyterhub-user-kkharbanda90%26redirect_uri%3D%252Fuser%252Fkkharbanda90%252Foauth_callback%26response_type%3Dcode%26state%3DeyJ1dWlkIjogImM2YTQ3NWIxZTg2ZDQzZTE4OGM1NDFkNTE4NjM1ZGQ0IiwgIm5leHRfdXJsIjogIi91c2VyL2traGFyYmFuZGE5MC9sYWIvL2hvbWUvanVweXRlci1ra2hhcmJhbmRhOTAvZGF0YS56aXAifQ
# Reusing existing connection to cainvas.ai-tech.systems:9000.
# HTTP request sent, awaiting response... 200 OK
# Length: 4677 (4.6K) [text/html]
# Saving to: ‘data.zip.1’
#
# data.zip.1          100%[===================>]   4.57K  --.-KB/s    in 0s
#
# 2021-08-21 08:02:42 (119 MB/s) - ‘data.zip.1’ saved [4677/4677]

# %%
#Loading the data file using pandas library

data = pd.read_csv('data.csv', sep = ",")
data.head(3)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38           122.8     1001.0
# 1    842517         M        20.57         17.77           132.9     1326.0
# 2  84300903         M        19.69         21.25           130.0     1203.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
# 2  ...          25.53            152.5      1709.0            0.1444
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
#
# [3 rows x 33 columns]

# %%
print(data.isna().sum())
data = data.dropna(axis = 1)
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
data.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33            184.6      2019.0
# 1  ...         24.99          23.41            158.8      1956.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
#
# [2 rows x 32 columns]

# %%
data.hist(figsize = (18,18))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'radius_mean'}>,
#         <AxesSubplot:title={'center':'texture_mean'}>,
#         <AxesSubplot:title={'center':'perimeter_mean'}>,
#         <AxesSubplot:title={'center':'area_mean'}>,
#         <AxesSubplot:title={'center':'smoothness_mean'}>],
#        [<AxesSubplot:title={'center':'compactness_mean'}>,
#         <AxesSubplot:title={'center':'concavity_mean'}>,
#         <AxesSubplot:title={'center':'concave points_mean'}>,
#         <AxesSubplot:title={'center':'symmetry_mean'}>,
#         <AxesSubplot:title={'center':'fractal_dimension_mean'}>,
#         <AxesSubplot:title={'center':'radius_se'}>],
#        [<AxesSubplot:title={'center':'texture_se'}>,
#         <AxesSubplot:title={'center':'perimeter_se'}>,
#         <AxesSubplot:title={'center':'area_se'}>,
#         <AxesSubplot:title={'center':'smoothness_se'}>,
#         <AxesSubplot:title={'center':'compactness_se'}>,
#         <AxesSubplot:title={'center':'concavity_se'}>],
#        [<AxesSubplot:title={'center':'concave points_se'}>,
#         <AxesSubplot:title={'center':'symmetry_se'}>,
#         <AxesSubplot:title={'center':'fractal_dimension_se'}>,
#         <AxesSubplot:title={'center':'radius_worst'}>,
#         <AxesSubplot:title={'center':'texture_worst'}>,
#         <AxesSubplot:title={'center':'perimeter_worst'}>],
#        [<AxesSubplot:title={'center':'area_worst'}>,
#         <AxesSubplot:title={'center':'smoothness_worst'}>,
#         <AxesSubplot:title={'center':'compactness_worst'}>,
#         <AxesSubplot:title={'center':'concavity_worst'}>,
#         <AxesSubplot:title={'center':'concave points_worst'}>,
#         <AxesSubplot:title={'center':'symmetry_worst'}>],
#        [<AxesSubplot:title={'center':'fractal_dimension_worst'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
# Plotting a heatmap/correlation plot to see how different values are related to each other
plt.figure(figsize=(30,24))
sns.heatmap(data.corr(),annot=True,linewidths=2)
plt.show()

# %%
# Encoding our diagnostics using label encoder

le = LabelEncoder()
data.iloc[:,1] = le.fit_transform(data.iloc[:,1].values)

# %%
print(data.shape)
X = data.iloc[:, 2:31].values
y = data.iloc[:,1].values

# Splitting our dataset into train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X, y,test_size = 0.3,random_state = 0, stratify = y)
# Out:
# (569, 32)

# %%
#Feature Scaling

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# convert the data to categorical labels

from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(Y_train, num_classes=None)
Y_test = to_categorical(Y_test, num_classes=None)
print ("Y = ",Y_train.shape)
print ("X = ",X_train.shape)
# Out:
# Y =  (398, 2)
# X =  (398, 29)

# %%
# Defining the architecture of our deep learning model

model = Sequential()

model.add(Dense(100, activation = "relu", input_dim = 29))
model.add(Dropout(0.2))
model.add(Dense(100, activation = "relu"))
model.add(Dense(2, activation = "softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               3000
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 13,302
# Trainable params: 13,302
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
# Run the model for a batch size of 35 for 100 epochs
history = model.fit(X_train, 
                    Y_train, 
                    validation_data = (X_test, Y_test),
                    batch_size = 35,
                    epochs = 100
                   )
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4176 - accuracy: 0.8191 - val_loss: 0.2426 - val_accuracy: 0.9298
# Epoch 2/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1761 - accuracy: 0.9523 - val_loss: 0.1708 - val_accuracy: 0.9357
# Epoch 3/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1187 - accuracy: 0.9648 - val_loss: 0.1448 - val_accuracy: 0.9474
# Epoch 4/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9724 - val_loss: 0.1330 - val_accuracy: 0.9474
# Epoch 5/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0701 - accuracy: 0.9774 - val_loss: 0.1252 - val_accuracy: 0.9415
# Epoch 6/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 0.9874 - val_loss: 0.1312 - val_accuracy: 0.9415
# Epoch 7/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0486 - accuracy: 0.9925 - val_loss: 0.1338 - val_accuracy: 0.9415
# Epoch 8/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0466 - accuracy: 0.9899 - val_loss: 0.1323 - val_accuracy: 0.9415
# Epoch 9/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 0.9925 - val_loss: 0.1365 - val_accuracy: 0.9357
# Epoch 10/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9925 - val_loss: 0.1408 - val_accuracy: 0.9415
# Epoch 11/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 0.9950 - val_loss: 0.1379 - val_accuracy: 0.9357
# Epoch 12/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0306 - accuracy: 0.9925 - val_loss: 0.1416 - val_accuracy: 0.9474
# Epoch 13/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 0.9975 - val_loss: 0.1433 - val_accuracy: 0.9415
# Epoch 14/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 0.9925 - val_loss: 0.1346 - val_accuracy: 0.9415
# Epoch 15/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 0.9925 - val_loss: 0.1334 - val_accuracy: 0.9415
# Epoch 16/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 0.9950 - val_loss: 0.1420 - val_accuracy: 0.9474
# Epoch 17/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9925 - val_loss: 0.1505 - val_accuracy: 0.9415
# Epoch 18/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.1564 - val_accuracy: 0.9357
# Epoch 19/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 0.9975 - val_loss: 0.1544 - val_accuracy: 0.9474
# Epoch 20/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 0.9975 - val_loss: 0.1609 - val_accuracy: 0.9357
# Epoch 21/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9950 - val_loss: 0.1585 - val_accuracy: 0.9357
# Epoch 22/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9975 - val_loss: 0.1536 - val_accuracy: 0.9474
# Epoch 23/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9474
# Epoch 24/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9950 - val_loss: 0.1570 - val_accuracy: 0.9532
# Epoch 25/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 0.1534 - val_accuracy: 0.9532
# Epoch 26/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.1607 - val_accuracy: 0.9532
# Epoch 27/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.1669 - val_accuracy: 0.9474
# Epoch 28/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1710 - val_accuracy: 0.9532
# Epoch 29/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.1738 - val_accuracy: 0.9474
# Epoch 30/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1801 - val_accuracy: 0.9474
# Epoch 31/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2029 - val_accuracy: 0.9474
# Epoch 32/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.2055 - val_accuracy: 0.9474
# Epoch 33/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1963 - val_accuracy: 0.9474
# Epoch 34/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1869 - val_accuracy: 0.9474
# Epoch 35/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9474
# Epoch 36/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1906 - val_accuracy: 0.9474
# Epoch 37/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9357
# Epoch 38/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9474
# Epoch 39/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2409 - val_accuracy: 0.9474
# Epoch 40/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9532
# Epoch 41/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2670 - val_accuracy: 0.9532
# Epoch 42/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2590 - val_accuracy: 0.9532
# Epoch 43/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.9975 - val_loss: 0.2233 - val_accuracy: 0.9357
# Epoch 44/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.9975 - val_loss: 0.2426 - val_accuracy: 0.9240
# Epoch 45/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.2473 - val_accuracy: 0.9357
# Epoch 46/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9357
# Epoch 47/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9357
# Epoch 48/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9975 - val_loss: 0.2388 - val_accuracy: 0.9357
# Epoch 49/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2420 - val_accuracy: 0.9357
# Epoch 50/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2329 - val_accuracy: 0.9357
# Epoch 51/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9357
# Epoch 52/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2326 - val_accuracy: 0.9357
# Epoch 53/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2351 - val_accuracy: 0.9415
# Epoch 54/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2279 - val_accuracy: 0.9415
# Epoch 55/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9474
# Epoch 56/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.3046e-04 - accuracy: 1.0000 - val_loss: 0.2184 - val_accuracy: 0.9474
# Epoch 57/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.6454e-04 - accuracy: 1.0000 - val_loss: 0.2165 - val_accuracy: 0.9474
# Epoch 58/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.8202e-04 - accuracy: 1.0000 - val_loss: 0.2155 - val_accuracy: 0.9474
# Epoch 59/100
# 12/12 [==============================] - 0s 3ms/step - loss: 4.2685e-04 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9532
# Epoch 60/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2147 - val_accuracy: 0.9474
# Epoch 61/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9415
# Epoch 62/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.4461e-04 - accuracy: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9357
# Epoch 63/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9415
# Epoch 64/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.8247e-04 - accuracy: 1.0000 - val_loss: 0.2186 - val_accuracy: 0.9415
# Epoch 65/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.3924e-04 - accuracy: 1.0000 - val_loss: 0.2191 - val_accuracy: 0.9415
# Epoch 66/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9415
# Epoch 67/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9415
# Epoch 68/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.3930e-04 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9474
# Epoch 69/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.8362e-04 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9532
# Epoch 70/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 0.9975 - val_loss: 0.1883 - val_accuracy: 0.9649
# Epoch 71/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1827 - val_accuracy: 0.9649
# Epoch 72/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1833 - val_accuracy: 0.9649
# Epoch 73/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9591
# Epoch 74/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.4376e-04 - accuracy: 1.0000 - val_loss: 0.2153 - val_accuracy: 0.9591
# Epoch 75/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.1941e-04 - accuracy: 1.0000 - val_loss: 0.2209 - val_accuracy: 0.9532
# Epoch 76/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2753 - val_accuracy: 0.9532
# Epoch 77/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.3016e-04 - accuracy: 1.0000 - val_loss: 0.2913 - val_accuracy: 0.9532
# Epoch 78/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2911 - val_accuracy: 0.9532
# Epoch 79/100
# 12/12 [==============================] - 0s 3ms/step - loss: 3.2202e-04 - accuracy: 1.0000 - val_loss: 0.2896 - val_accuracy: 0.9532
# Epoch 80/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.1335e-04 - accuracy: 1.0000 - val_loss: 0.2885 - val_accuracy: 0.9532
# Epoch 81/100
# 12/12 [==============================] - 0s 3ms/step - loss: 4.7679e-04 - accuracy: 1.0000 - val_loss: 0.2871 - val_accuracy: 0.9532
# Epoch 82/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.2792e-04 - accuracy: 1.0000 - val_loss: 0.2766 - val_accuracy: 0.9532
# Epoch 83/100
# 12/12 [==============================] - 0s 3ms/step - loss: 3.3878e-04 - accuracy: 1.0000 - val_loss: 0.2629 - val_accuracy: 0.9532
# Epoch 84/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.8860e-04 - accuracy: 1.0000 - val_loss: 0.2584 - val_accuracy: 0.9474
# Epoch 85/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9729e-04 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9474
# Epoch 86/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.9589e-04 - accuracy: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.9474
# Epoch 87/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5161e-04 - accuracy: 1.0000 - val_loss: 0.2597 - val_accuracy: 0.9474
# Epoch 88/100
# 12/12 [==============================] - 0s 3ms/step - loss: 4.6658e-04 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9532
# Epoch 89/100
# 12/12 [==============================] - 0s 3ms/step - loss: 3.7331e-04 - accuracy: 1.0000 - val_loss: 0.2550 - val_accuracy: 0.9532
# Epoch 90/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2559 - val_accuracy: 0.9474
# Epoch 91/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2751 - val_accuracy: 0.9415
# Epoch 92/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5964e-04 - accuracy: 1.0000 - val_loss: 0.2936 - val_accuracy: 0.9415
# Epoch 93/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.9415
# Epoch 94/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.8682e-04 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9415
# Epoch 95/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9426e-04 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9532
# Epoch 96/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.0463e-04 - accuracy: 1.0000 - val_loss: 0.2544 - val_accuracy: 0.9532
# Epoch 97/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7949e-04 - accuracy: 1.0000 - val_loss: 0.2506 - val_accuracy: 0.9532
# Epoch 98/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6542e-04 - accuracy: 1.0000 - val_loss: 0.2485 - val_accuracy: 0.9532
# Epoch 99/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.9981e-04 - accuracy: 1.0000 - val_loss: 0.2488 - val_accuracy: 0.9532
# Epoch 100/100
# 12/12 [==============================] - 0s 3ms/step - loss: 3.5237e-04 - accuracy: 1.0000 - val_loss: 0.2513 - val_accuracy: 0.9532

# %%
# Function to plot "accuracy vs epoch" graphs and "loss vs epoch" graphs for training and validation data
def plot_metrics(model_name, metric = 'accuracy'):
    if metric == 'loss':
        plt.title("Loss Values")
        plt.plot(model_name.history['loss'], label = 'train')
        plt.plot(model_name.history['val_loss'], label = 'test')
        plt.legend()
        plt.show()
    else:
        plt.title("Accuracy Values")
        plt.plot(model_name.history['accuracy'], label='train') 
        plt.plot(model_name.history['val_accuracy'], label='test') 
        plt.legend()
        plt.show()

# %%
plot_metrics(history, 'accuracy')
plot_metrics(history, 'loss')

# %%
# Saving our trained model
from tensorflow.keras.models import save_model
if os.path.isfile('best_model.h5') is False:
    model.save('best_model.h5')

# %%
#Plotting a confusion matrix for checking the performance of our model
Y_pred = np.argmax(model.predict(X_test), axis = 1)
cnf = confusion_matrix(Y_test.argmax(axis = 1), Y_pred)


df_cnf = pd.DataFrame(cnf, range(2), range(2))
sns.set(font_scale = 2)
sns.heatmap(df_cnf, annot = True)
plt.title("Confusion Matrix")
plt.show()
